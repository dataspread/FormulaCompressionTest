# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Test result path (CHANGE)
testPath = "C:\\Users\\jonat\\Documents\\Dataspread\\FormulaCompressionTest\\Chris\\FormulaCompressionTesting\\testing\\reports\\rq1"



def getMetrics(path, miscDict):
    """
    Takes in a path string to a .stat file and returns a Pandas DataFrame of the file's contents
    """
    reportsFile = open(path, 'r')
    dataDict = {}
    for key in miscDict:
        dataDict[key] = []
    for key in miscDict:
        dataDict[key].append(miscDict[key])
    for line in reportsFile:
        if ': ' in line:
            metric, value = line.split(": ")
            if metric not in dataDict:
                dataDict[metric] = []
            try:
                dataDict[metric].append(int(value))
            except ValueError:
                dataDict[metric].append(float(value))
            except:
                dataDict[metric].append(value)
    reportsFile.close
    return pd.DataFrame(dataDict)


def getAllMetrics(basePath, miscDict={'sync type':'', 'mem type':'', 'impl':'', 'test':'', 'run':0}):
    """
    Takes in a file path and searches all of its subdirectories for .stat files and returns all of
    their contents in a Pandas DataFrame
    """
    data = pd.DataFrame()
    for file in os.listdir(basePath):
        filePath = os.path.join(basePath, file)
        if os.path.isdir(filePath):
            updateMiscDict(miscDict, file)
            data = data.append(getAllMetrics(filePath, miscDict))
        elif file == "core.stat":
            data = data.append(getMetrics(filePath, miscDict))
    
    return data

def updateMiscDict(miscDict, miscData):
    if miscData.lower() in ['async', 'sync']:
        miscDict['sync type'] = miscData
    elif miscData.lower() in ['inmem', 'db']:
        miscDict['mem type'] = miscData
    elif miscData.lower() in ['comp', 'pgimpl', 'async']:
        miscDict['impl'] = miscData
    elif miscData.lower() in ['runnigtotalfast', 'runningtotalslow', 'rate']:
        miscDict['test'] = miscData
    elif miscData.split('-')[0].lower() in ['run']:
        miscDict['run'] = int(miscData.split('-')[1])

def summarizeTest(testData, x=["Number of cells to update"], y=['Total test time (ms)', 'Total time of getting dependents (ms)']):
    """
    Plots the test results given in testData on the given x and y values
    """
    testData = testData.groupby(x).mean()
    ax = testData.plot.bar(y=y, subplots=True, figsize=(12,8))
    for pltIndex in np.arange(len(y)):
        ax[pltIndex].set_ylabel('Time in ms')

# %%
# use the helper function to plot
pd.set_option('max_rows', 90)
display(getAllMetrics(testPath))
#summarizeTest(getAllMetrics(testPath))
# Out:
#   sync type mem type    impl              test  run  Total test time (ms)  \
# 0     Async       DB          RunningTotalSlow    1                300242
# 0     Async       DB          RunningTotalSlow    1               1221487
# 0     Async       DB          RunningTotalSlow    1               1439536
# 0     Async       DB          RunningTotalSlow    1               2498934
# 0     Async       DB          RunningTotalSlow    1                 93607
# 0     Async       DB          RunningTotalSlow    2                301209
# 0     Async       DB          RunningTotalSlow    2               1345869
# 0     Async       DB          RunningTotalSlow    2               1461074
# 0     Async       DB          RunningTotalSlow    2               2622550
# 0     Async       DB          RunningTotalSlow    2                 98178
# 0     Async       DB          RunningTotalSlow    3                293072
# 0     Async       DB          RunningTotalSlow    3               1205383
# 0     Async       DB          RunningTotalSlow    3               1297390
# 0     Async       DB          RunningTotalSlow    3               2494621
# 0     Async       DB          RunningTotalSlow    3                 99582
# 0     Async       DB    Comp  RunningTotalSlow    1                 60692
# 0     Async       DB    Comp  RunningTotalSlow    1                 92751
# 0     Async       DB    Comp  RunningTotalSlow    1                146359
# 0     Async       DB    Comp  RunningTotalSlow    1                203674
# 0     Async       DB    Comp  RunningTotalSlow    1                 31874
# 0     Async       DB    Comp  RunningTotalSlow    2                 62628
# 0     Async       DB    Comp  RunningTotalSlow    2                 98399
# 0     Async       DB    Comp  RunningTotalSlow    2                152066
# 0     Async       DB    Comp  RunningTotalSlow    2                207730
# 0     Async       DB    Comp  RunningTotalSlow    2                 31537
# 0     Async       DB    Comp  RunningTotalSlow    3                 61848
# 0     Async       DB    Comp  RunningTotalSlow    3                 99250
# 0     Async       DB    Comp  RunningTotalSlow    3                149469
# 0     Async       DB    Comp  RunningTotalSlow    3                203529
# 0     Async       DB    Comp  RunningTotalSlow    3                 32632
# 0     Async       DB  PGImpl  RunningTotalSlow    1                 61180
# 0     Async       DB  PGImpl  RunningTotalSlow    1                107476
# 0     Async       DB  PGImpl  RunningTotalSlow    1                162508
# 0     Async       DB  PGImpl  RunningTotalSlow    1                226780
# 0     Async       DB  PGImpl  RunningTotalSlow    1                 31486
# 0     Async       DB  PGImpl  RunningTotalSlow    2                124025
# 0     Async       DB  PGImpl  RunningTotalSlow    2                108982
# 0     Async       DB  PGImpl  RunningTotalSlow    2                161483
# 0     Async       DB  PGImpl  RunningTotalSlow    2                224171
# 0     Async       DB  PGImpl  RunningTotalSlow    2                 35208
# 0     Async       DB  PGImpl  RunningTotalSlow    3                126028
# 0     Async       DB  PGImpl  RunningTotalSlow    3                106462
# 0     Async       DB  PGImpl  RunningTotalSlow    3                160406
# 0     Async       DB  PGImpl  RunningTotalSlow    3                220086
# 0     Async       DB  PGImpl  RunningTotalSlow    3                 34504
# 0     Async       DB  PGImpl  RunningTotalSlow    1                293039
# 0     Async       DB  PGImpl  RunningTotalSlow    1               1210609
# 0     Async       DB  PGImpl  RunningTotalSlow    1               1483917
# 0     Async       DB  PGImpl  RunningTotalSlow    1               2769568
# 0     Async       DB  PGImpl  RunningTotalSlow    1                101067
# 0     Async       DB  PGImpl  RunningTotalSlow    2                303494
# 0     Async       DB  PGImpl  RunningTotalSlow    2               1195812
# 0     Async       DB  PGImpl  RunningTotalSlow    2               1610191
# 0     Async       DB  PGImpl  RunningTotalSlow    2               2638667
# 0     Async       DB  PGImpl  RunningTotalSlow    2                 96079
# 0     Async       DB  PGImpl  RunningTotalSlow    3                306039
# 0     Async       DB  PGImpl  RunningTotalSlow    3               1348545
# 0     Async       DB  PGImpl  RunningTotalSlow    3               1639619
# 0     Async       DB  PGImpl  RunningTotalSlow    3               2760024
# 0     Async       DB  PGImpl  RunningTotalSlow    3                 95320
# 0     Async       DB    Comp  RunningTotalSlow    1                 62605
# 0     Async       DB    Comp  RunningTotalSlow    1                102427
# 0     Async       DB    Comp  RunningTotalSlow    1                149622
# 0     Async       DB    Comp  RunningTotalSlow    1                207976
# 0     Async       DB    Comp  RunningTotalSlow    1                 31032
# 0     Async       DB    Comp  RunningTotalSlow    2                 62213
# 0     Async       DB    Comp  RunningTotalSlow    2                100135
# 0     Async       DB    Comp  RunningTotalSlow    2                146119
# 0     Async       DB    Comp  RunningTotalSlow    2                218808
# 0     Async       DB    Comp  RunningTotalSlow    2                 31310
# 0     Async       DB    Comp  RunningTotalSlow    3                 62215
# 0     Async       DB    Comp  RunningTotalSlow    3                 98524
# 0     Async       DB    Comp  RunningTotalSlow    3                169701
# 0     Async       DB    Comp  RunningTotalSlow    3                219255
# 0     Async       DB    Comp  RunningTotalSlow    3                 32592
# 0     Async       DB  PGImpl  RunningTotalSlow    1                 64298
# 0     Async       DB  PGImpl  RunningTotalSlow    1                104039
# 0     Async       DB  PGImpl  RunningTotalSlow    1                160238
# 0     Async       DB  PGImpl  RunningTotalSlow    1                216455
# 0     Async       DB  PGImpl  RunningTotalSlow    1                 31868
# 0     Async       DB  PGImpl  RunningTotalSlow    2                126833
# 0     Async       DB  PGImpl  RunningTotalSlow    2                105800
# 0     Async       DB  PGImpl  RunningTotalSlow    2                160492
# 0     Async       DB  PGImpl  RunningTotalSlow    2                227838
# 0     Async       DB  PGImpl  RunningTotalSlow    2                 65692
# 0     Async       DB  PGImpl  RunningTotalSlow    3                 73535
# 0     Async       DB  PGImpl  RunningTotalSlow    3                111960
# 0     Async       DB  PGImpl  RunningTotalSlow    3                167299
# 0     Async       DB  PGImpl  RunningTotalSlow    3                232317
# 0     Async       DB  PGImpl  RunningTotalSlow    3                 35351
#
#    Number of cells to update  Number of cells updated  \
# 0                      10001                    10001
# 0                      15001                    15001
# 0                      20001                    20001
# 0                      25001                    25001
# 0                       5001                     5001
# 0                      10001                    10001
# 0                      15001                    15001
# 0                      20001                    20001
# 0                      25001                    25001
# 0                       5001                     5001
# 0                      10001                    10001
# 0                      15001                    15001
# 0                      20001                    20001
# 0                      25001                    25001
# 0                       5001                     5001
# 0                      10001                    10001
# 0                      15001                    15001
# 0                      20001                    20001
# 0                      25001                    25001
# 0                       5001                     5001
# 0                      10001                    10001
# 0                      15001                    15001
# 0                      20001                    20001
# 0                      25001                    25001
# 0                       5001                     5001
# 0                      10001                    10001
# 0                      15001                    15001
# 0                      20001                    20001
# 0                      25001                    25001
# 0                       5001                     5001
# 0                      10001                    10001
# 0                      15001                    15001
# 0                      20001                    20001
# 0                      25001                    25001
# 0                       5001                     5001
# 0                      10001                    10001
